# %% [markdown]
# <a href="https://colab.research.google.com/github/pame-olguin/challenge1-data-science-latam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_tienda1=int(tienda["Precio"].sum())
ingreso_tienda2=int(tienda2["Precio"].sum())
ingreso_tienda3=int(tienda3["Precio"].sum())
ingreso_tienda4=int(tienda4["Precio"].sum())

# %%
print("Ingreso Tienda 1:",ingreso_tienda1)
print("Ingreso Tienda 2:",ingreso_tienda2)
print("Ingreso Tienda 3:",ingreso_tienda3)
print("Ingreso Tienda 4:",ingreso_tienda4)
# Out:
# Ingreso Tienda 1: 1150880400
# Ingreso Tienda 2: 1116343500
# Ingreso Tienda 3: 1098019600
# Ingreso Tienda 4: 1038375700

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
from matplotlib import pyplot as plt

# %%
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
ingresos = [ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4]

plt.bar(tiendas, ingresos)
plt.xlabel("Tiendas")
plt.ylabel("Ingresos")
plt.title("Ingresos por Tienda")

plt.show()

# %%
tienda_mayor_ingresos = max(ingresos)
tienda_menor_ingresos = min(ingresos)

print("Tienda con mayor ingreso:", tiendas[ingresos.index(tienda_mayor_ingresos)])
print("Tienda con menor ingreso:", tiendas[ingresos.index(tienda_menor_ingresos)])
# Out:
# Tienda con mayor ingreso: Tienda 1
# Tienda con menor ingreso: Tienda 4

# %% [markdown]
# # 2. Ventas por categoría

# %%
print("Columnas en tienda:", tienda.columns)
print("Columnas en tienda2:", tienda2.columns)
print("Columnas en tienda3:", tienda3.columns)
print("Columnas en tienda4:", tienda4.columns)
# Out:
# Columnas en tienda: Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')
# Columnas en tienda2: Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')
# Columnas en tienda3: Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')
# Columnas en tienda4: Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
# ...

# %%
categoria_tienda1 = tienda["Categoría del Producto"].value_counts()
categoria_tienda2 = tienda2["Categoría del Producto"].value_counts()
categoria_tienda3 = tienda3["Categoría del Producto"].value_counts()
categoria_tienda4 = tienda4["Categoría del Producto"].value_counts()

# %%
print("Ventas por categoría en Tienda 1:")
print(categoria_tienda1)
# Out:
# Ventas por categoría en Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
bar = plt.bar(categoria_tienda1.index, categoria_tienda1.values)
plt.xlabel("Categoría del Producto")
plt.ylabel("Cantidad de Ventas")
plt.title("Ventas por Categoría en Tienda 1")
plt.xticks(rotation=45)
plt.show()

# %%
print("Ventas por categoría en Tienda 2:")
print(categoria_tienda2)
# Out:
# Ventas por categoría en Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
bar = plt.bar(categoria_tienda2.index, categoria_tienda2.values)
plt.xlabel("Categoría del Producto")
plt.ylabel("Cantidad de Ventas")
plt.title("Ventas por Categoría en Tienda 2")
plt.xticks(rotation=45)
plt.show()

# %%
print("Ventas por categoría en Tienda 3:")
print(categoria_tienda3)
# Out:
# Ventas por categoría en Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
bar = plt.bar(categoria_tienda3.index, categoria_tienda3.values)
plt.xlabel("Categoría del Producto")
plt.ylabel("Cantidad de Ventas")
plt.title("Ventas por Categoría en Tienda 3")
plt.xticks(rotation=45)
plt.show()

# %%
print("Ventas por categoría en Tienda 4:")
print(categoria_tienda4)
# Out:
# Ventas por categoría en Tienda 4:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
bar = plt.bar(categoria_tienda4.index, categoria_tienda4.values)
plt.xlabel("Categoría del Producto")
plt.ylabel("Cantidad de Ventas")
plt.title("Ventas por Categoría en Tienda 4")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_tienda1 = tienda["Calificación"].mean()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
